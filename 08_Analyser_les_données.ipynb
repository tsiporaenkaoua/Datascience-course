# %%
import pandas as pd
df= pd.read_csv("data.csv")

# %%
df['price_paid'].describe()#1000 lignes remplies, 528 lignes uniques...
# Out:
# count      1000
# unique      528
# top       $3.73
# freq          8
# Name: price_paid, dtype: object

# %%
df.price_paid = df.price_paid.apply(lambda x: x.replace("$",""))#df.price_paid peut aussi etre représenté de cette maniere : df["price_paid"]
df.price_paid =df.price_paid.astype(float) # changer le type d'une donnée

# %%
df['price_paid'].mean()#calcule de la moyenne
# Out:
# 6.461930000000001

# %%
df['price_paid'].sum()#calcule de la somme
# Out:
# 6461.93

# %%
df['price_paid'].min()#prix minimal
# Out:
# 3.0

# %%
df['price_paid'].max()
# Out:
# 10.0

# %%
df['country'].unique()#Toutes les valeurs possibles pour la colonne country
# Out:
# array(['Canada', 'United States', 'Morocco', 'France', nan], dtype=object)

# %%
df['price_paid'].unique().tolist()
# Out:
# [5.36,
#  8.32,
#  3.73,
#  3.7,
#  9.24,
#  5.82,
#  6.29,
#  3.01,
#  9.05,
#  5.71,
#  3.15,
#  5.3,
#  5.97,
#  4.53,
#  4.1,
#  6.44,
#  3.16,
#  4.9,
#  5.55,
#  4.86,
#  6.72,
#  9.79,
#  8.23,
#  9.9,
#  5.88,
#  3.06,
#  9.52,
#  6.76,
#  7.81,
#  6.02,
#  5.0,
#  5.34,
#  4.67,
#  6.22,
#  3.37,
#  9.5,
#  4.54,
#  4.04,
#  3.45,
#  4.96,
#  5.29,
#  8.11,
#  7.8,
#  4.21,
#  9.81,
#  9.7,
#  9.71,
#  3.88,
#  3.4,
#  9.23,
#  6.57,
#  9.99,
#  6.94,
#  4.26,
#  9.13,
#  6.66,
#  9.35,
#  3.04,
#  6.17,
#  7.68,
#  4.23,
#  4.69,
#  7.56,
#  5.92,
#  4.65,
#  6.79,
#  8.71,
#  8.96,
#  4.39,
#  7.54,
#  5.83,
#  6.39,
#  9.6,
#  9.68,
#  9.86,
#  5.53,
#  3.51,
#  8.43,
#  6.89,
#  6.68,
#  4.66,
#  4.95,
#  6.77,
#  7.48,
#  7.23,
#  8.12,
#  5.8,
#  6.06,
#  4.71,
#  7.78,
#  9.67,
#  9.93,
#  4.56,
#  4.42,
#  4.12,
#  4.32,
#  8.83,
#  3.18,
#  8.86,
#  7.2,
#  3.72,
#  7.67,
#  8.68,
#  9.58,
#  7.91,
#  7.65,
#  8.77,
#  7.17,
#  9.47,
#  8.97,
#  6.07,
#  9.89,
# ...

# %%
df['country'].value_counts()#nombre de clients par pays
# Out:
# country
# France           408
# United States    333
# Canada           161
# Morocco           54
# Name: count, dtype: int64

# %%
df['gender'].value_counts(normalize=True)
# Out:
# gender
# Female    0.529538
# Male      0.470462
# Name: proportion, dtype: float64

# %%
df.groupby("country").sum()#on peut en retirer la somme de CA groupé par pays
# Out:
#                    id                                               date  \
# country
# Canada          70365  03/28/202103/19/202103/14/202103/09/202103/11/...
# France         214440  03/08/202103/23/202103/24/202103/16/202103/12/...
# Morocco         26591  03/24/202103/28/202103/22/202103/28/202103/21/...
# United States  168150  03/17/202103/19/202103/25/202103/16/202103/21/...
#
#                                                       first_name  \
# country
# Canada         MarylinHindaAvaWaylonLiefJaniceSibealMendieMur...
# France         CodiGuglielmaCullJudyeJeffreyJilleneTreschaCha...
# Morocco        KanyaTommiToniaPenelopeRandyLayKristalEthelinW...
# United States  ErlGrataTitosBailieOralieJulinaEveEstaNobeElys...
#
#                                                        last_name  \
# country
# Canada         AldersHarridgeKencottHeersemaWoodcraftMorillas...
# France         FeasleyGookesVassieBehanStanmanBaudiMcCuddenGr...
# ...

# %%
df.groupby("gender")["price_paid"].mean()#comparer 2 colonnes
# Out:
# gender
# Female    6.420406
# Male      6.469429
# Name: price_paid, dtype: float64

# %%
df.dtypes
# Out:
# id              int64
# date           object
# first_name     object
# last_name      object
# email          object
# gender         object
# ip_address     object
# country        object
# price_paid    float64
# tax           float64
# dtype: object

# %%
df.groupby(["gender", "country"]).mean(numeric_only=True)
# Out:
#                               id  price_paid   tax
# gender country
# Female Canada         461.472973    6.419324  20.0
#        France         512.648241    6.350352  20.0
#        Morocco        479.925926    7.024815  20.0
#        United States  487.282353    6.437118  20.0
# Male   Canada         406.000000    6.117467  20.0
#        France         534.928177    6.498950  20.0
#        Morocco        483.652174    6.146957  20.0
#        United States  525.284722    6.672500  20.0
